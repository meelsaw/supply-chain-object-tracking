# %%
import torch
from matplotlib import pyplot as plt
from PIL import Image
import os
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Use your local YOLOv5 submodule
model = torch.hub.load('../yolov5', 'yolov5s', source='local')  # or yolov5n for nano model

# Confirm it's loaded
print(model)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/mohamedelsawy/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /Users/mohamedelsawy/PycharmProjects/supply-chain-object-tracking/notebooks/../yolov5/utils/general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.7 torch-2.7.1 CPU
#
# ...
# 100%|██████████████████████████████████████| 14.1M/14.1M [00:01<00:00, 13.5MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# ...

# %%
# Load test image
img_path = '../data/test_image_2.jpg'  # replace with your file name
img = Image.open(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x400>

# %%
# Inference
results = model(img)

# Show results
results.print()     # Console summary
results.show()      # Display image with boxes
# Out:
# /Users/mohamedelsawy/PycharmProjects/supply-chain-object-tracking/notebooks/../yolov5/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 400x711 10 birds, 1 kite
# Speed: 7.0ms pre-process, 88.4ms inference, 0.6ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=711x400>
